# %%
from gensim import models

# %%
model = models.Word2Vec(sentences, size=100, window=5, min_count=5, workers=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1e6678159270> in <module>()
# ----> 1 model = models.Word2Vec(sentences, size=100, window=5, min_count=5, workers=4)
#
# NameError: name 'sentences' is not defined

# %%
from nltk.corpus import brown, movie_reviews, treebank

# %%
b = models.Word2Vec(brown.sents())

# %%
mr = models.Word2Vec(movie_reviews.sents())
t = models.Word2Vec(treebank.sents())

# %%
mr.most_similar('sex', topn=5)
# Out:
# [(u'nudity', 0.6074498891830444),
#  (u'explosions', 0.5708829164505005),
#  (u'sexual', 0.5520691275596619),
#  (u'drugs', 0.5467973947525024),
#  (u'ingenious', 0.5421402454376221)]

# %%
for word in mr.vocab:
    print mr.most_similar(word, topn=3)
# Out:
# [(u'comforting', 0.7619376182556152), (u'darnell', 0.7571429014205933), (u'thrilled', 0.7378161549568176)]
# [(u'publishing', 0.6989181041717529), (u'professors', 0.6840169429779053), (u'cruising', 0.6822499632835388)]
# [(u'oversized', 0.6814817190170288), (u'resides', 0.6810281276702881), (u'electrical', 0.6754113435745239)]
# [(u'six', 0.7665725946426392), (u'three', 0.7473872900009155), (u'twenty', 0.7429945468902588)]
# [(u'107', 0.7351036667823792), (u'phony', 0.6700680255889893), (u'cliche', 0.6677447557449341)]
# [(u'coach', 0.7376764416694641), (u'reverend', 0.735991895198822), (u'foreman', 0.7254924774169922)]
# [(u'vacation', 0.6533640623092651), (u'rumble', 0.6493299007415771), (u'salinger', 0.5892547965049744)]
# [(u'elliot', 0.7046254277229309), (u'annie', 0.6932458877563477), (u'vitti', 0.6861704587936401)]
# [(u'sara', 0.7295020222663879), (u'nicky', 0.72878497838974), (u'loren', 0.7266996502876282)]
# ...
